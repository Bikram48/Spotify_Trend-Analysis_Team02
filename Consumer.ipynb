# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem
import boto3

# %%
consumer = KafkaConsumer(
    'spotify_topic',
     bootstrap_servers=['0.0.0.0'], #add your IP here
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
session = boto3.Session()
s3 = session.client('s3')

def upload_data_to_s3(data, bucket_name, key):
    # Convert data to JSON string
    data_json = json.dumps(data)
    
    # Upload data to S3
    response = s3.put_object(
        Body=data_json,
        Bucket=bucket_name,
        Key=key
    )
    print(f"Data uploaded to S3 with response: {response}")

# %%
bucket_name = "spotifydsci6007"

for count, i in enumerate(consumer):
    data = i.value  # Consumed data
    print(data)
    # Upload data to S3
    upload_data_to_s3(data, bucket_name, "track_{}.json".format(count))
# Out:
# {'Track ID': '59xD5osEFsaNt5PXfIKUnX', 'Track Name': 'Illusion', 'Album': 'Illusion', 'Artist': 'Dua Lipa', 'Genres': ['dance pop', 'pop', 'uk pop'], 'Track URI': 'spotify:track:59xD5osEFsaNt5PXfIKUnX', 'Audio Features': {'danceability': 0.679, 'energy': 0.772, 'key': 8, 'loudness': -4.721, 'mode': 0, 'speechiness': 0.0472, 'acousticness': 0.0277, 'instrumentalness': 2.59e-06, 'liveness': 0.106, 'valence': 0.709, 'tempo': 126.964, 'type': 'audio_features', 'id': '59xD5osEFsaNt5PXfIKUnX', 'uri': 'spotify:track:59xD5osEFsaNt5PXfIKUnX', 'track_href': 'https://api.spotify.com/v1/tracks/59xD5osEFsaNt5PXfIKUnX', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/59xD5osEFsaNt5PXfIKUnX', 'duration_ms': 188143, 'time_signature': 4}}
# ...

# %%
import boto3

session = boto3.Session()
# Initialize the S3 client
s3 = session.client('s3')

# Specify the bucket name and JSON file path
bucket_name = 'dsci6007bchan'
json_file_path = '/Users/bikram/Downloads/data/log_data/2018/11/2018-11-03-events.json'

# Specify the key (name) under which the file will be stored in S3
key_name = 'files/your-json-file.json'

# Upload the file to S3
try:
    s3.upload_file(json_file_path, bucket_name, key_name)
    print("File uploaded successfully.")
except Exception as e:
    print(f"Error uploading file: {e}")
# Out:
# File uploaded successfully.

# %%
import boto3

AWS_S3_BUCKET_NAME = 'spotifydsci6007'
AWS_REGION = 'us-east-1'
AWS_ACCESS_KEY = 'ASIAZQ3DTGBKYFZZ5N6A'
AWS_SECRET_KEY = 'gGWXPmrcA7nUE9BdCfo6oyz5e90UThrrB7+2U3Kd'

LOCAL_FILE = '/Users/bikram/Downloads/data/log_data/2018/11/2018-11-01-events.json'
NAME_FOR_S3 = '01-events.json'

def main():
    print('in main method')

    s3_client = boto3.client(
        service_name='s3',
        region_name=AWS_REGION,
        aws_access_key_id=AWS_ACCESS_KEY,
        aws_secret_access_key=AWS_SECRET_KEY
    )

    response = s3_client.upload_file(LOCAL_FILE, AWS_S3_BUCKET_NAME, NAME_FOR_S3)

    print(f'upload_log_to_aws response: {response}')

if __name__ == '__main__':
    main()
# Out:
# in main method
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/boto3/s3/transfer.py:371, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     370 try:
# --> 371     future.result()
#     372 # If a client error was raised, add the backwards compatibility layer
#     373 # that raises a S3UploadFailedError. These specific errors were only
#     374 # ever thrown for upload_parts but now can be thrown for any related
#     375 # client error.
#
# File ~/anaconda3/lib/python3.11/site-packages/s3transfer/futures.py:103, in TransferFuture.result(self)
#      99 try:
#     100     # Usually the result() method blocks until the transfer is done,
#     101     # however if a KeyboardInterrupt is raised we want want to exit
#     102     # out of this and propagate the exception.
# ...

# %%
import boto3

def list_s3_buckets():
    # Create a session using the default profile
    session = boto3.Session()
    
    # Create an S3 client using the session
    s3 = session.client('s3')

    # List S3 buckets
    try:
        response = s3.list_buckets()
        buckets = [bucket['Name'] for bucket in response['Buckets']]
        print("List of S3 buckets:")
        for bucket in buckets:
            print(bucket)
    except Exception as e:
        print(f"Error listing buckets: {e}")

if __name__ == "__main__":
    list_s3_buckets()
# Out:
# List of S3 buckets:
# aws-logs-654654517333-us-east-1
# bikram.chand.cs79a.bucket
# dsci.workshop
# dsci6007.s02.gluelab.bikram
# dsci6007bchan
# glue-1950-buckett
# lab5bchan9sdjfjkk
# lab5hadoopdsci6007bchan
# logs.bikram.chand.cs79a.bucket
# mybucket5327
# newbucket20222
# sparkify3bucketbchandsci007
# sparkify5dsci6007bchan9
# sparkify5outputbchan9
# sparkify6outputbchan9
# spotifydsci6007
# www.bikram.chand.cs79a.bucket
